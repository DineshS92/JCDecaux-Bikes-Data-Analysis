# %% [markdown]
# # Author: Dinesh Sadhwani

# %% [markdown]
# ### **Objective:** Extract data from the JCDecaux API over a period of 3 days before Christmas 2021 (19 Dec - 22 Dec) and 3 days after Christmas 2021 (26 Dec - 29 Dec)

# %% [markdown]
# #### **Problem:** JCDecaux API server provide fresh bikes data every minute. However, past data is never stored on their server or maybe it is, but JCDecaux does not provide access to it. So, if we need to collect data over a period of time, 3 days in our case, we would have to keep the python script running for that period.
#
# #### **Solution:** We setup a Virtual Machine (VM) instance on Google Cloud Platform which acts like a server that runs the script for the desired amount of time. Every 30 mins the pandas dataframe that collects the data was converted to a csv file and stored on the hard disk of the VM instance. Once the 3-days data collection period was finished, the data was copied to a Google Cloud Storage Bucket, so that the VM instance could be shut down to save hourly costs.

# %% [markdown]
# ## Phase 1: Get raw data
# By the end of this phase we get a two sets of csv file with each set containing the pre- and post-Christmas bikes data.

# %%
# importing all the necessary libraries

import os
import requests
import pandas as pd
import time
import datetime
import glob

# %%
# setup all the necessary variables for the loop that constantly queries the API server. These variables remain the same for 
# both pre-christmas and post-christmas data

# 3 days = 4320 minutes, which is how long the loop will run
number_of_minutes = 4320

# this variable tells the loop to write the dataframe to csv file as described in the solution above
write_interval = 30

# the API key used for authentication
API_KEY = "2cca7c8c88124160de93f6619ea071b40b90ce44"

URL = "https://api.jcdecaux.com/vls/v3/stations?"

# this list defines the 4 cities for which we are pulling the data
CITIES = ["lyon", "dublin", "bruxelles", "toyama"]

# %%
# initialize the pandas dataframe that will hold the 30 minutes bike data

bikes_data_df = pd.DataFrame()

# %% [markdown]
# As far as the loop to call the API is concerned, there are two separate loop for each separate set of 3 days

# %% [markdown]
# #### **Loop for 19 Dec to 22 Dec**

# %%
# loop starts at minute 1 instead of minute 0

for _ in range(1, number_of_minutes + 1):
    for city in CITIES:
        bikes = URL + "contract=" + city + "&apiKey=" + API_KEY
        response = requests.get(bikes)
        data = response.json()
        df = pd.DataFrame(data)
        bikes_data_df = bikes_data_df.append(df, ignore_index=True)

    # this if control statement ensures that the dataframe is written to csv every 30 minutes and 
    # the bikes_data_df is freed up to hold data of the next 30 minutes

    if _ % write_interval == 0:

        # the columns that contain complex json objects are split into columns and then dropped

        bikes_data_df = bikes_data_df.join(
            pd.json_normalize(bikes_data_df["totalStands"].tolist()).add_prefix("totalStands_")).join(
            pd.json_normalize(bikes_data_df["mainStands"].tolist()).add_prefix("mainStands_")).drop(
            ["totalStands", "mainStands", "overflowStands"], axis=1)

        # it is usually the case that certain bike stations don't have any activities for several minutes, so for each minute, 
        # the API server refreshes, we may get repeated data. 
        # The pandas drop_duplicates() function ensures that duplicates are dropped,
        # and therefore the csv file contains unique rows

        bikes_data_df = bikes_data_df.drop_duplicates(subset=["number", "contractName", "lastUpdate"])

        bikes_data_df.to_csv(f"./pre_christmas/pre_christmas_{datetime.datetime.now().strftime('%d_%m_%H_%M_%S')}.csv", index=False)
        
        # once the csv file is created for our 30 minute data, the bikes_data_df variable is freed up to gather data for the next 30 minute segment

        bikes_data_df = pd.DataFrame()
 
    # this final one line of code is perhaps the most important part. If we let the for loop run without this, the script could overload the server with requests
    # and our account may get banned. Also, since the API server updates the data every minute, this script helps synchronize with the server

    time.sleep(60)

# %% [markdown]
# #### **Loop for 26 Dec to 29 Dec - This is same as the previous for loop. Only difference is that the path and file name changes in the pd.to_csv() function**

# %%
# loop starts at minute 1 instead of minute 0

for _ in range(1, number_of_minutes + 1):
    for city in CITIES:
        bikes = URL + "contract=" + city + "&apiKey=" + API_KEY
        response = requests.get(bikes)
        data = response.json()
        df = pd.DataFrame(data)
        bikes_data_df = bikes_data_df.append(df, ignore_index=True)

    # this if control statement ensures that the dataframe is written to csv every 30 minutes and 
    # the bikes_data_df is freed up to hold data of the next 30 minutes

    if _ % write_interval == 0:

        # the columns that contain complex json objects are split into columns and then dropped

        bikes_data_df = bikes_data_df.join(
            pd.json_normalize(bikes_data_df["totalStands"].tolist()).add_prefix("totalStands_")).join(
            pd.json_normalize(bikes_data_df["mainStands"].tolist()).add_prefix("mainStands_")).drop(
            ["totalStands", "mainStands", "overflowStands"], axis=1)

        # it is usually the case that certain bike stations don't have any activities for several minutes, so for each minute, 
        # the API server refreshes, we may get repeated data. 
        # The pandas drop_duplicates() function ensures that duplicates are dropped,
        # and therefore the csv file contains unique rows

        bikes_data_df = bikes_data_df.drop_duplicates(subset=["number", "contractName", "lastUpdate"])

        bikes_data_df.to_csv(f"./post_christmas/post_christmas_{datetime.datetime.now().strftime('%d_%m_%H_%M_%S')}.csv", index=False)
        
        # once the csv file is created for our 30 minute data, the bikes_data_df variable is freed up to gather data for the next 30 minute segment

        bikes_data_df = pd.DataFrame()
 
    # this final one line of code is perhaps the most important part. If we let the for loop run without this, the script could overload the server with requests
    # and our account may get banned. Also, since the API server updates the data every minute, this script helps synchronize with the server

    time.sleep(60)

# %% [markdown]
# ## Phase 2 (this part can be run in the notebook)
# In this phase we process each collection of csv files to make it suitable for data analysis.

# %%
# the very first step is to combine each 3-days csv file collection into a single dataframe

pre_christmas_bikes_df = pd.concat([pd.read_csv(f) for f in glob.glob("./data/jcd-data-prechristmas/" + "*.csv")],
                      ignore_index=True)

post_christmas_bikes_df = pd.concat([pd.read_csv(f) for f in glob.glob("./data/jcd-data-postchristmas/" + "*.csv")],
                      ignore_index=True)

# %%
# although we have made sure that we drop duplicated in the 30 minutes dataframe segments, there are duplicates
# because we have combined the files

pre_christmas_bikes_df[pre_christmas_bikes_df.duplicated(subset=["number", "contractName", "lastUpdate"], keep=False)]\
.sort_values("lastUpdate")
# Out:
#         number contractName               name  \
# 284637     286    bruxelles         286 - BENS
# 454535     286    bruxelles         286 - BENS
# 192620     286    bruxelles         286 - BENS
# 458422     286    bruxelles         286 - BENS
# 614986     286    bruxelles         286 - BENS
# ...        ...          ...                ...
# 640472     138    bruxelles   138 - HOUFFALIZE
# 639762     138    bruxelles   138 - HOUFFALIZE
# 640249      11       dublin  EARLSFORT TERRACE
# 639781     259    bruxelles      259 - NOVILLE
# 640615     259    bruxelles      259 - NOVILLE
#
#                                                   address  \
# 284637  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 454535  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 192620  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 458422  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 614986  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# ...                                                   ...
# 640472  HOUFFALIZE - PLACE DE HOUFFALIZE /HOUFFALIZEPL...
# 639762  HOUFFALIZE - PLACE DE HOUFFALIZE /HOUFFALIZEPL...
# 640249                                  Earlsfort Terrace
# 639781                               NOVILLE - SQ NOVILLE
# 640615                               NOVILLE - SQ NOVILLE
#
#                                                position  banking  bonus  \
# 284637   {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 454535   {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 192620   {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 458422   {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 614986   {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# ...                                                 ...      ...    ...
# 640472   {'latitude': 50.865218, 'longitude': 4.377735}    False  False
# 639762   {'latitude': 50.865218, 'longitude': 4.377735}    False  False
# 640249  {'latitude': 53.334295, 'longitude': -6.258503}    False  False
# 639781    {'latitude': 50.859608, 'longitude': 4.33409}    False  False
# 640615    {'latitude': 50.859608, 'longitude': 4.33409}    False  False
#
#         status            lastUpdate  connected  ...  \
# 284637  CLOSED  2021-09-30T08:37:53Z      False  ...
# 454535  CLOSED  2021-09-30T08:37:53Z      False  ...
# 192620  CLOSED  2021-09-30T08:37:53Z      False  ...
# 458422  CLOSED  2021-09-30T08:37:53Z      False  ...
# 614986  CLOSED  2021-09-30T08:37:53Z      False  ...
# ...        ...                   ...        ...  ...
# 640472    OPEN  2021-12-22T22:40:49Z       True  ...
# 639762    OPEN  2021-12-22T22:40:49Z       True  ...
# 640249    OPEN  2021-12-22T22:40:49Z       True  ...
# 639781    OPEN  2021-12-22T22:40:50Z       True  ...
# 640615    OPEN  2021-12-22T22:40:50Z       True  ...
#
#         totalStands_availabilities.electricalBikes  \
# 284637                                           0
# 454535                                           0
# 192620                                           0
# 458422                                           0
# 614986                                           0
# ...                                            ...
# 640472                                           6
# 639762                                           6
# 640249                                           3
# 639781                                           8
# 640615                                           8
#
#         totalStands_availabilities.electricalInternalBatteryBikes  \
# 284637                                                  0
# 454535                                                  0
# 192620                                                  0
# 458422                                                  0
# 614986                                                  0
# ...                                                   ...
# 640472                                                  0
# 639762                                                  0
# 640249                                                  0
# 639781                                                  0
# 640615                                                  0
#
#         totalStands_availabilities.electricalRemovableBatteryBikes  \
# 284637                                                  0
# 454535                                                  0
# 192620                                                  0
# 458422                                                  0
# 614986                                                  0
# ...                                                   ...
# 640472                                                  6
# 639762                                                  6
# 640249                                                  3
# 639781                                                  8
# 640615                                                  8
#
#         mainStands_capacity  mainStands_availabilities.bikes  \
# 284637                   20                                0
# 454535                   20                                0
# 192620                   20                                0
# 458422                   20                                0
# 614986                   20                                0
# ...                     ...                              ...
# 640472                   25                               14
# 639762                   25                               14
# 640249                   30                                6
# 639781                   20                                9
# 640615                   20                                9
#
#         mainStands_availabilities.stands  \
# 284637                                 0
# 454535                                 0
# 192620                                 0
# 458422                                 0
# 614986                                 0
# ...                                  ...
# 640472                                11
# 639762                                11
# 640249                                24
# 639781                                11
# 640615                                11
#
#         mainStands_availabilities.mechanicalBikes  \
# 284637                                          0
# 454535                                          0
# 192620                                          0
# 458422                                          0
# 614986                                          0
# ...                                           ...
# 640472                                          8
# 639762                                          8
# 640249                                          3
# 639781                                          1
# 640615                                          1
#
#         mainStands_availabilities.electricalBikes  \
# 284637                                          0
# 454535                                          0
# 192620                                          0
# 458422                                          0
# 614986                                          0
# ...                                           ...
# 640472                                          6
# 639762                                          6
# 640249                                          3
# 639781                                          8
# 640615                                          8
#
#         mainStands_availabilities.electricalInternalBatteryBikes  \
# 284637                                                  0
# 454535                                                  0
# 192620                                                  0
# 458422                                                  0
# 614986                                                  0
# ...                                                   ...
# 640472                                                  0
# 639762                                                  0
# 640249                                                  0
# 639781                                                  0
# 640615                                                  0
#
#         mainStands_availabilities.electricalRemovableBatteryBikes
# 284637                                                  0
# 454535                                                  0
# 192620                                                  0
# 458422                                                  0
# 614986                                                  0
# ...                                                   ...
# 640472                                                  6
# 639762                                                  6
# 640249                                                  3
# 639781                                                  8
# 640615                                                  8
#
# [224824 rows x 26 columns]

# %%
post_christmas_bikes_df[post_christmas_bikes_df.duplicated(subset=["number", "contractName", "lastUpdate"], keep=False)]\
.sort_values("lastUpdate")
# Out:
#         number contractName                            name  \
# 514925     286    bruxelles                      286 - BENS
# 189461     286    bruxelles                      286 - BENS
# 453157     286    bruxelles                      286 - BENS
# 457650     286    bruxelles                      286 - BENS
# 193333     286    bruxelles                      286 - BENS
# ...        ...          ...                             ...
# 585415    1023         lyon  1023 - CROIX ROUSSE / PERFETTI
# 585310    7057         lyon         7057 - JAURES / BOLLIER
# 585787    7057         lyon         7057 - JAURES / BOLLIER
# 585259    7038         lyon         7038 - PLACE STALINGRAD
# 585400    7038         lyon         7038 - PLACE STALINGRAD
#
#                                                   address  \
# 514925  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 189461  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 453157  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 457650  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# 193333  BENS - CHEE D'ALSEMBERG DEVANT LE 548 / ALSEMB...
# ...                                                   ...
# 585415                          16 BVD DE LA CROIX-ROUSSE
# 585310             217b–221 Avenue Jean Jaurès 69007 Lyon
# 585787             217b–221 Avenue Jean Jaurès 69007 Lyon
# 585259                        Angle Rue de la Guillotiere
# 585400                        Angle Rue de la Guillotiere
#
#                                               position  banking  bonus  \
# 514925  {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 189461  {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 453157  {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 457650  {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# 193333  {'latitude': 50.807811, 'longitude': 4.336789}    False  False
# ...                                                ...      ...    ...
# 585415  {'latitude': 45.772229, 'longitude': 4.819389}    False   True
# 585310  {'latitude': 45.734712, 'longitude': 4.835486}     True  False
# 585787  {'latitude': 45.734712, 'longitude': 4.835486}     True  False
# 585259   {'latitude': 45.749622, 'longitude': 4.85299}    False  False
# 585400   {'latitude': 45.749622, 'longitude': 4.85299}    False  False
#
#         status            lastUpdate  connected  ...  \
# 514925  CLOSED  2021-09-30T08:37:53Z      False  ...
# 189461  CLOSED  2021-09-30T08:37:53Z      False  ...
# 453157  CLOSED  2021-09-30T08:37:53Z      False  ...
# 457650  CLOSED  2021-09-30T08:37:53Z      False  ...
# 193333  CLOSED  2021-09-30T08:37:53Z      False  ...
# ...        ...                   ...        ...  ...
# 585415    OPEN  2021-12-29T07:32:03Z       True  ...
# 585310    OPEN  2021-12-29T07:32:04Z       True  ...
# 585787    OPEN  2021-12-29T07:32:04Z       True  ...
# 585259    OPEN  2021-12-29T07:32:05Z       True  ...
# 585400    OPEN  2021-12-29T07:32:05Z       True  ...
#
#         totalStands_availabilities.electricalBikes  \
# 514925                                           0
# 189461                                           0
# 453157                                           0
# 457650                                           0
# 193333                                           0
# ...                                            ...
# 585415                                           4
# 585310                                           5
# 585787                                           5
# 585259                                           2
# 585400                                           2
#
#         totalStands_availabilities.electricalInternalBatteryBikes  \
# 514925                                                  0
# 189461                                                  0
# 453157                                                  0
# 457650                                                  0
# 193333                                                  0
# ...                                                   ...
# 585415                                                  0
# 585310                                                  0
# 585787                                                  0
# 585259                                                  0
# 585400                                                  0
#
#         totalStands_availabilities.electricalRemovableBatteryBikes  \
# 514925                                                  0
# 189461                                                  0
# 453157                                                  0
# 457650                                                  0
# 193333                                                  0
# ...                                                   ...
# 585415                                                  4
# 585310                                                  5
# 585787                                                  5
# 585259                                                  2
# 585400                                                  2
#
#         mainStands_capacity  mainStands_availabilities.bikes  \
# 514925                   20                                0
# 189461                   20                                0
# 453157                   20                                0
# 457650                   20                                0
# 193333                   20                                0
# ...                     ...                              ...
# 585415                   20                               14
# 585310                   34                               14
# 585787                   34                               14
# 585259                   13                               10
# 585400                   13                               10
#
#         mainStands_availabilities.stands  \
# 514925                                 0
# 189461                                 0
# 453157                                 0
# 457650                                 0
# 193333                                 0
# ...                                  ...
# 585415                                 6
# 585310                                20
# 585787                                20
# 585259                                 3
# 585400                                 3
#
#         mainStands_availabilities.mechanicalBikes  \
# 514925                                          0
# 189461                                          0
# 453157                                          0
# 457650                                          0
# 193333                                          0
# ...                                           ...
# 585415                                         10
# 585310                                          9
# 585787                                          9
# 585259                                          8
# 585400                                          8
#
#         mainStands_availabilities.electricalBikes  \
# 514925                                          0
# 189461                                          0
# 453157                                          0
# 457650                                          0
# 193333                                          0
# ...                                           ...
# 585415                                          4
# 585310                                          5
# 585787                                          5
# 585259                                          2
# 585400                                          2
#
#         mainStands_availabilities.electricalInternalBatteryBikes  \
# 514925                                                  0
# 189461                                                  0
# 453157                                                  0
# 457650                                                  0
# 193333                                                  0
# ...                                                   ...
# 585415                                                  0
# 585310                                                  0
# 585787                                                  0
# 585259                                                  0
# 585400                                                  0
#
#         mainStands_availabilities.electricalRemovableBatteryBikes
# 514925                                                  0
# 189461                                                  0
# 453157                                                  0
# 457650                                                  0
# 193333                                                  0
# ...                                                   ...
# 585415                                                  4
# 585310                                                  5
# 585787                                                  5
# 585259                                                  2
# 585400                                                  2
#
# [229449 rows x 26 columns]

# %%
# so now we proceed to drop the duplicates by subsetting using number, contractName, and lastUpdate. The combination
# of these 3 attributes uniquely define each row

pre_christmas_bikes_df = pre_christmas_bikes_df.drop_duplicates(subset=["number", "contractName", "lastUpdate"])

post_christmas_bikes_df = post_christmas_bikes_df.drop_duplicates(subset=["number", "contractName", "lastUpdate"])

# %%
# finally we write the dataframes to csv files for importing in the analysis notebook

pre_christmas_bikes_df.to_csv("./data/jcd-pre-christmas-data.csv", index=False)

post_christmas_bikes_df.to_csv("./data/jcd-post-christmas-data.csv", index=False)
